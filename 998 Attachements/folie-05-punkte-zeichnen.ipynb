# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
x = np.array ([-7, 13, 2])

# %%
x
# Out:
# array([-7, 13,  2])

# %%
y = np.array ([-3, -5, 11])
y
# Out:
# array([-3, -5, 11])

# %%
pl.plot (x, y, 'o', color = 'blue')
